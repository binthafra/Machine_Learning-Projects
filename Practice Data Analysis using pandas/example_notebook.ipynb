# %% [markdown]
# # HEllow World

# %%
print ('HI this is afra ')
# Out:
# HI this is afra

# %%
a = 5

# %%
a = 6

# %%
a
# Out:
# 6

# %%
1+1
# Out:
# 2

# %% [markdown]
# ## Heart Disease Project
# Thhis project is about classifying whether or not a patient has heart disease

# %%
import pandas as pd

# %% [markdown]
# This table shows heart disease information

# %%
df =pd.read_csv("heart-disease.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.target.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
#     ![](6-step-ml-framework.png)

# %% [markdown]
# ![](6-step-ml-framework.png)

# %% [markdown]
# # Problem Definition
# This is the pronlem definition

# %% [markdown]
# # Data
# This is the data we're using

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 9880-C3B0
#
#  Directory of C:\Users\HP\Desktop\ML_Course\sample_project
#
# 10/10/2020  08:36 PM    <DIR>          .
# 10/10/2020  08:36 PM    <DIR>          ..
# 10/09/2020  05:25 PM    <DIR>          .ipynb_checkpoints
# 10/09/2020  05:23 PM           332,025 6-step-ml-framework.png
# 10/10/2020  08:27 PM               116 debug.log
# 10/09/2020  05:21 PM    <DIR>          env
# 10/10/2020  08:36 PM            13,333 example_notebook.ipynb
# 10/09/2020  05:23 PM            11,328 heart-disease.csv
#                4 File(s)        356,802 bytes
#                4 Dir(s)  153,008,246,784 bytes free

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.
